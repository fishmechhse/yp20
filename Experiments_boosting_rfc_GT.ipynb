# %%
import pandas as pd
import optuna
import lightgbm
import xgboost
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv('clean_data_for_training.csv')

# %%
X = df.drop(['target'], axis=1)
y = df['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 10, 1000)
    learning_rate = trial.suggest_float('learning_rate', 0.01, 0.5)
    max_depth = trial.suggest_int('max_depth', 2, 20)
    subsample = trial.suggest_float('subsample', 0.5, 1.0)
    min_child_samples = trial.suggest_int('min_child_samples', 1, 10)
    model_lgbm = LGBMClassifier(
        n_estimators=n_estimators,
        learning_rate=learning_rate,
        max_depth=max_depth,
        subsample=subsample,
        min_child_samples=min_child_samples
    )
    model_lgbm.fit(X_train, y_train)
    pred_lgbm = model_lgbm.predict(X_test)
    accuracy = accuracy_score(y_test, pred_lgbm)
    return accuracy
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2025-03-03 12:26:40,496] A new study created in memory with name: no-name-55c892ce-3c30-42ad-b3e9-ac90364a0873
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002845 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2025-03-03 12:26:41,126] Trial 0 finished with value: 0.8227593152064451 and parameters: {'n_estimators': 425, 'learning_rate': 0.20407350958438472, 'max_depth': 3, 'subsample': 0.5675586290930852, 'min_child_samples': 4}. Best is trial 0 with value: 0.8227593152064451.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002800 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2025-03-03 12:26:41,289] Trial 1 finished with value: 0.8214165827458879 and parameters: {'n_estimators': 156, 'learning_rate': 0.37993139127810094, 'max_depth': 3, 'subsample': 0.8156332342681707, 'min_child_samples': 7}. Best is trial 0 with value: 0.8227593152064451.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003327 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [I 2025-03-03 12:26:42,364] Trial 2 finished with value: 0.8197381671701913 and parameters: {'n_estimators': 415, 'learning_rate': 0.25782579246282283, 'max_depth': 7, 'subsample': 0.8603811763383948, 'min_child_samples': 6}. Best is trial 0 with value: 0.8227593152064451.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002977 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [I 2025-03-03 12:26:42,839] Trial 3 finished with value: 0.8338368580060423 and parameters: {'n_estimators': 141, 'learning_rate': 0.04086765497029264, 'max_depth': 9, 'subsample': 0.5795529574062657, 'min_child_samples': 2}. Best is trial 3 with value: 0.8338368580060423.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002561 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003351 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [I 2025-03-03 12:28:15,047] Trial 81 finished with value: 0.8271231957032561 and parameters: {'n_estimators': 347, 'learning_rate': 0.041705362015985535, 'max_depth': 14, 'subsample': 0.5881627935688017, 'min_child_samples': 1}. Best is trial 27 with value: 0.8358509566968781.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003327 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [I 2025-03-03 12:28:16,370] Trial 82 finished with value: 0.8277945619335347 and parameters: {'n_estimators': 388, 'learning_rate': 0.06823602083180111, 'max_depth': 15, 'subsample': 0.7923753521585624, 'min_child_samples': 1}. Best is trial 27 with value: 0.8358509566968781.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002509 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [I 2025-03-03 12:28:17,483] Trial 83 finished with value: 0.8214165827458879 and parameters: {'n_estimators': 292, 'learning_rate': 0.41300643769989676, 'max_depth': 16, 'subsample': 0.6191696611739551, 'min_child_samples': 1}. Best is trial 27 with value: 0.8358509566968781.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002713 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [I 2025-03-03 12:28:19,061] Trial 84 finished with value: 0.8345082242363209 and parameters: {'n_estimators': 462, 'learning_rate': 0.026915064534206633, 'max_depth': 13, 'subsample': 0.5300381977088205, 'min_child_samples': 2}. Best is trial 27 with value: 0.8358509566968781.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003417 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [I 2025-03-03 12:28:20,676] Trial 85 finished with value: 0.8298086606243706 and parameters: {'n_estimators': 499, 'learning_rate': 0.024418438706928305, 'max_depth': 12, 'subsample': 0.5279565031660407, 'min_child_samples': 5}. Best is trial 27 with value: 0.8358509566968781.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003379 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [I 2025-03-03 12:28:22,549] Trial 86 finished with value: 0.8230949983215844 and parameters: {'n_estimators': 542, 'learning_rate': 0.05936360243497345, 'max_depth': 11, 'subsample': 0.5485698650174327, 'min_child_samples': 2}. Best is trial 27 with value: 0.8358509566968781.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003050 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [I 2025-03-03 12:28:22,999] Trial 87 finished with value: 0.8170527022490769 and parameters: {'n_estimators': 117, 'learning_rate': 0.21651710647964956, 'max_depth': 12, 'subsample': 0.5563516117032858, 'min_child_samples': 3}. Best is trial 27 with value: 0.8358509566968781.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002531 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [I 2025-03-03 12:28:24,305] Trial 88 finished with value: 0.8298086606243706 and parameters: {'n_estimators': 448, 'learning_rate': 0.03515047876214306, 'max_depth': 7, 'subsample': 0.5138339916956003, 'min_child_samples': 2}. Best is trial 27 with value: 0.8358509566968781.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003272 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [I 2025-03-03 12:28:25,781] Trial 89 finished with value: 0.8227593152064451 and parameters: {'n_estimators': 461, 'learning_rate': 0.07972188081689159, 'max_depth': 10, 'subsample': 0.5716516204573947, 'min_child_samples': 4}. Best is trial 27 with value: 0.8358509566968781.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002665 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [I 2025-03-03 12:28:27,229] Trial 90 finished with value: 0.8308157099697885 and parameters: {'n_estimators': 419, 'learning_rate': 0.020857303446780495, 'max_depth': 15, 'subsample': 0.5267124670101172, 'min_child_samples': 2}. Best is trial 27 with value: 0.8358509566968781.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002498 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [I 2025-03-03 12:28:28,356] Trial 91 finished with value: 0.8254447801275596 and parameters: {'n_estimators': 331, 'learning_rate': 0.049303877615331025, 'max_depth': 14, 'subsample': 0.5795149497467018, 'min_child_samples': 1}. Best is trial 27 with value: 0.8358509566968781.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002716 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [I 2025-03-03 12:28:29,672] Trial 92 finished with value: 0.8341725411211816 and parameters: {'n_estimators': 373, 'learning_rate': 0.03813887809628175, 'max_depth': 13, 'subsample': 0.5998437319340146, 'min_child_samples': 1}. Best is trial 27 with value: 0.8358509566968781.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002492 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [I 2025-03-03 12:28:30,928] Trial 93 finished with value: 0.8301443437395098 and parameters: {'n_estimators': 374, 'learning_rate': 0.034608880179012216, 'max_depth': 13, 'subsample': 0.6309426267228561, 'min_child_samples': 2}. Best is trial 27 with value: 0.8358509566968781.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002591 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [I 2025-03-03 12:28:32,758] Trial 94 finished with value: 0.8345082242363209 and parameters: {'n_estimators': 512, 'learning_rate': 0.010242208496953958, 'max_depth': 13, 'subsample': 0.5422818591328022, 'min_child_samples': 1}. Best is trial 27 with value: 0.8358509566968781.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003659 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [I 2025-03-03 12:28:34,654] Trial 95 finished with value: 0.8351795904665995 and parameters: {'n_estimators': 519, 'learning_rate': 0.01029856238294588, 'max_depth': 13, 'subsample': 0.5390347932954457, 'min_child_samples': 1}. Best is trial 27 with value: 0.8358509566968781.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002771 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [I 2025-03-03 12:28:36,435] Trial 96 finished with value: 0.8133601879825445 and parameters: {'n_estimators': 518, 'learning_rate': 0.26122085174209314, 'max_depth': 12, 'subsample': 0.5382964281211232, 'min_child_samples': 1}. Best is trial 27 with value: 0.8358509566968781.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003663 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [I 2025-03-03 12:28:38,331] Trial 97 finished with value: 0.8308157099697885 and parameters: {'n_estimators': 479, 'learning_rate': 0.020598199088538438, 'max_depth': 13, 'subsample': 0.5954839099348681, 'min_child_samples': 1}. Best is trial 27 with value: 0.8358509566968781.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003317 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [I 2025-03-03 12:28:40,225] Trial 98 finished with value: 0.8345082242363209 and parameters: {'n_estimators': 501, 'learning_rate': 0.0188568143135363, 'max_depth': 10, 'subsample': 0.5075561826945562, 'min_child_samples': 1}. Best is trial 27 with value: 0.8358509566968781.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002531 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644
# [I 2025-03-03 12:28:42,356] Trial 99 finished with value: 0.8257804632426989 and parameters: {'n_estimators': 620, 'learning_rate': 0.06189639930541653, 'max_depth': 9, 'subsample': 0.5011564408073348, 'min_child_samples': 1}. Best is trial 27 with value: 0.8358509566968781.

# %%
model_lgbm = LGBMClassifier(**study.best_params)
model_lgbm.fit(X_train, y_train)
pred_lgbm = model_lgbm.predict(X_test)
precision_lgbm = precision_score(y_test, pred_lgbm, pos_label='NORM')
recall_lgbm = recall_score(y_test, pred_lgbm, pos_label='NORM')
f1_lgbm = f1_score(y_test, pred_lgbm, pos_label='NORM')
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4283, number of negative: 4652
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003828 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17142
# [LightGBM] [Info] Number of data points in the train set: 8935, number of used features: 78
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.479351 -> initscore=-0.082644
# [LightGBM] [Info] Start training from score -0.082644

# %%
print('Precision:', precision_lgbm)
print('Recall:', recall_lgbm)
print('F1:', f1_lgbm)
# Out:
# Precision: 0.8170504044803982
# Recall: 0.8706896551724138
# F1: 0.8430176565008025

# %%
label_encoder = LabelEncoder()
y_train_enc = label_encoder.fit_transform(y_train)
y_test_enc = label_encoder.fit_transform(y_test)
def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 10, 1000)
    learning_rate = trial.suggest_float('learning_rate', 0.01, 0.5)
    max_depth = trial.suggest_int('max_depth', 2, 20)
    subsample = trial.suggest_float('subsample', 0.5, 1.0)
    min_child_weight = trial.suggest_int('min_child_weight', 1, 10)
    model_xgb = XGBClassifier(
        n_estimators=n_estimators,
        learning_rate=learning_rate,
        max_depth=max_depth,
        subsample=subsample,
        min_child_weight=min_child_weight
    )
    model_xgb.fit(X_train, y_train_enc)
    pred_xgb = model_xgb.predict(X_test)
    accuracy = accuracy_score(y_test_enc, pred_xgb)
    return accuracy
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2025-03-03 12:28:43,049] A new study created in memory with name: no-name-ec122920-9387-4b81-a45c-8db3523ad65f
# [I 2025-03-03 12:28:49,375] Trial 0 finished with value: 0.8130245048674052 and parameters: {'n_estimators': 645, 'learning_rate': 0.1460930699587452, 'max_depth': 14, 'subsample': 0.7499789888664083, 'min_child_weight': 4}. Best is trial 0 with value: 0.8130245048674052.
# [I 2025-03-03 12:28:52,133] Trial 1 finished with value: 0.8049681101040618 and parameters: {'n_estimators': 546, 'learning_rate': 0.45131616858719187, 'max_depth': 6, 'subsample': 0.6293367047064995, 'min_child_weight': 4}. Best is trial 0 with value: 0.8130245048674052.
# [I 2025-03-03 12:28:54,189] Trial 2 finished with value: 0.824773413897281 and parameters: {'n_estimators': 54, 'learning_rate': 0.07900676435989185, 'max_depth': 20, 'subsample': 0.8540061010988589, 'min_child_weight': 6}. Best is trial 2 with value: 0.824773413897281.
# [I 2025-03-03 12:28:58,746] Trial 3 finished with value: 0.8086606243705942 and parameters: {'n_estimators': 996, 'learning_rate': 0.3616731939014668, 'max_depth': 12, 'subsample': 0.8331478102642328, 'min_child_weight': 9}. Best is trial 2 with value: 0.824773413897281.
# [I 2025-03-03 12:29:00,235] Trial 4 finished with value: 0.8093319906008728 and parameters: {'n_estimators': 123, 'learning_rate': 0.32950992538994367, 'max_depth': 12, 'subsample': 0.9512582946079429, 'min_child_weight': 8}. Best is trial 2 with value: 0.824773413897281.
# [I 2025-03-03 12:29:07,412] Trial 5 finished with value: 0.8261161463578383 and parameters: {'n_estimators': 757, 'learning_rate': 0.01872026721367734, 'max_depth': 9, 'subsample': 0.6527212673709809, 'min_child_weight': 8}. Best is trial 5 with value: 0.8261161463578383.
# [I 2025-03-03 12:29:10,681] Trial 6 finished with value: 0.8116817724068479 and parameters: {'n_estimators': 547, 'learning_rate': 0.2579368490710525, 'max_depth': 12, 'subsample': 0.6595692705603968, 'min_child_weight': 10}. Best is trial 5 with value: 0.8261161463578383.
# [I 2025-03-03 12:29:10,988] Trial 7 finished with value: 0.8032896945283652 and parameters: {'n_estimators': 54, 'learning_rate': 0.4727782892345684, 'max_depth': 4, 'subsample': 0.5498946299094986, 'min_child_weight': 6}. Best is trial 5 with value: 0.8261161463578383.
# [I 2025-03-03 12:29:12,898] Trial 8 finished with value: 0.8126888217522659 and parameters: {'n_estimators': 179, 'learning_rate': 0.4059353008374823, 'max_depth': 9, 'subsample': 0.818256281776524, 'min_child_weight': 2}. Best is trial 5 with value: 0.8261161463578383.
# [I 2025-03-03 12:29:18,371] Trial 9 finished with value: 0.82040953340047 and parameters: {'n_estimators': 745, 'learning_rate': 0.3474941261880815, 'max_depth': 15, 'subsample': 0.6004076365646769, 'min_child_weight': 1}. Best is trial 5 with value: 0.8261161463578383.
# [I 2025-03-03 12:29:25,137] Trial 10 finished with value: 0.8331654917757637 and parameters: {'n_estimators': 922, 'learning_rate': 0.010661827216775971, 'max_depth': 7, 'subsample': 0.5122185923882506, 'min_child_weight': 8}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:29:31,714] Trial 11 finished with value: 0.828130245048674 and parameters: {'n_estimators': 899, 'learning_rate': 0.020237191832001688, 'max_depth': 7, 'subsample': 0.5445548408123358, 'min_child_weight': 8}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:29:33,932] Trial 12 finished with value: 0.8123531386371265 and parameters: {'n_estimators': 979, 'learning_rate': 0.16215522913865787, 'max_depth': 2, 'subsample': 0.5060103705586403, 'min_child_weight': 7}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:29:39,433] Trial 13 finished with value: 0.8180597515944948 and parameters: {'n_estimators': 868, 'learning_rate': 0.03612288200903638, 'max_depth': 7, 'subsample': 0.5028324375307124, 'min_child_weight': 10}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:29:41,446] Trial 14 finished with value: 0.8173883853642162 and parameters: {'n_estimators': 333, 'learning_rate': 0.13030975011848334, 'max_depth': 6, 'subsample': 0.713169223012588, 'min_child_weight': 8}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:29:43,323] Trial 15 finished with value: 0.8096676737160121 and parameters: {'n_estimators': 847, 'learning_rate': 0.21147897895612985, 'max_depth': 2, 'subsample': 0.5727024322092135, 'min_child_weight': 5}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:29:49,260] Trial 16 finished with value: 0.8214165827458879 and parameters: {'n_estimators': 866, 'learning_rate': 0.09944284110031465, 'max_depth': 9, 'subsample': 0.556277786037567, 'min_child_weight': 7}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:29:50,777] Trial 17 finished with value: 0.8308157099697885 and parameters: {'n_estimators': 368, 'learning_rate': 0.01417515521522856, 'max_depth': 4, 'subsample': 0.6981405193207378, 'min_child_weight': 9}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:29:52,118] Trial 18 finished with value: 0.8160456529036589 and parameters: {'n_estimators': 344, 'learning_rate': 0.21446049207032575, 'max_depth': 4, 'subsample': 0.9302337487269726, 'min_child_weight': 9}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:29:53,743] Trial 19 finished with value: 0.8241020476670023 and parameters: {'n_estimators': 328, 'learning_rate': 0.0717152069825623, 'max_depth': 5, 'subsample': 0.7077219317571988, 'min_child_weight': 10}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:29:57,058] Trial 20 finished with value: 0.8096676737160121 and parameters: {'n_estimators': 427, 'learning_rate': 0.28026050346009523, 'max_depth': 19, 'subsample': 0.8871540855587879, 'min_child_weight': 9}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:30:02,868] Trial 21 finished with value: 0.8284659281638134 and parameters: {'n_estimators': 655, 'learning_rate': 0.01829817400708686, 'max_depth': 8, 'subsample': 0.5996489774605188, 'min_child_weight': 7}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:30:08,288] Trial 22 finished with value: 0.8180597515944948 and parameters: {'n_estimators': 683, 'learning_rate': 0.06412449346816194, 'max_depth': 8, 'subsample': 0.6867263194574672, 'min_child_weight': 7}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:30:09,753] Trial 23 finished with value: 0.8254447801275596 and parameters: {'n_estimators': 459, 'learning_rate': 0.10596009652908589, 'max_depth': 3, 'subsample': 0.7756444322729755, 'min_child_weight': 5}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:30:11,055] Trial 24 finished with value: 0.8311513930849278 and parameters: {'n_estimators': 230, 'learning_rate': 0.03666335456802112, 'max_depth': 5, 'subsample': 0.6110460923696154, 'min_child_weight': 7}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:30:12,339] Trial 25 finished with value: 0.8049681101040618 and parameters: {'n_estimators': 245, 'learning_rate': 0.1975419651655605, 'max_depth': 5, 'subsample': 0.6171983061748604, 'min_child_weight': 9}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:30:13,219] Trial 26 finished with value: 0.8271231957032561 and parameters: {'n_estimators': 256, 'learning_rate': 0.05592915000762303, 'max_depth': 3, 'subsample': 0.7541040046634144, 'min_child_weight': 6}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:30:17,573] Trial 27 finished with value: 0.8177240684793555 and parameters: {'n_estimators': 469, 'learning_rate': 0.10700127210602207, 'max_depth': 10, 'subsample': 0.6603247407455217, 'min_child_weight': 8}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:30:19,602] Trial 28 finished with value: 0.8103390399462908 and parameters: {'n_estimators': 395, 'learning_rate': 0.17687761431415416, 'max_depth': 5, 'subsample': 0.5260527544779101, 'min_child_weight': 9}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:30:23,434] Trial 29 finished with value: 0.8220879489761665 and parameters: {'n_estimators': 226, 'learning_rate': 0.12250416928225909, 'max_depth': 14, 'subsample': 0.5823209183068412, 'min_child_weight': 3}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:30:27,780] Trial 30 finished with value: 0.8170527022490769 and parameters: {'n_estimators': 569, 'learning_rate': 0.05134877630989023, 'max_depth': 7, 'subsample': 0.7088305091178346, 'min_child_weight': 7}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:30:33,608] Trial 31 finished with value: 0.8328298086606244 and parameters: {'n_estimators': 637, 'learning_rate': 0.013395085535924101, 'max_depth': 8, 'subsample': 0.602161337528024, 'min_child_weight': 7}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:30:37,617] Trial 32 finished with value: 0.8328298086606244 and parameters: {'n_estimators': 596, 'learning_rate': 0.015996563092553033, 'max_depth': 6, 'subsample': 0.6211656725519287, 'min_child_weight': 6}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:30:41,614] Trial 33 finished with value: 0.8160456529036589 and parameters: {'n_estimators': 605, 'learning_rate': 0.08332977659426113, 'max_depth': 6, 'subsample': 0.626248224979477, 'min_child_weight': 4}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:30:50,010] Trial 34 finished with value: 0.8241020476670023 and parameters: {'n_estimators': 772, 'learning_rate': 0.043520624690756515, 'max_depth': 11, 'subsample': 0.5821302369953393, 'min_child_weight': 5}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:30:53,121] Trial 35 finished with value: 0.8140315542128231 and parameters: {'n_estimators': 514, 'learning_rate': 0.1427396698217896, 'max_depth': 6, 'subsample': 0.5293414361710828, 'min_child_weight': 6}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:30:58,869] Trial 36 finished with value: 0.8173883853642162 and parameters: {'n_estimators': 716, 'learning_rate': 0.0798594985341248, 'max_depth': 8, 'subsample': 0.6423634468276026, 'min_child_weight': 6}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:31:05,909] Trial 37 finished with value: 0.8190668009399127 and parameters: {'n_estimators': 627, 'learning_rate': 0.04058975361635689, 'max_depth': 10, 'subsample': 0.6076544571403271, 'min_child_weight': 5}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:31:12,864] Trial 38 finished with value: 0.8180597515944948 and parameters: {'n_estimators': 804, 'learning_rate': 0.08777620468434062, 'max_depth': 14, 'subsample': 0.6788370988619552, 'min_child_weight': 7}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:31:22,594] Trial 39 finished with value: 0.8304800268546492 and parameters: {'n_estimators': 940, 'learning_rate': 0.011486624026670217, 'max_depth': 10, 'subsample': 0.5665862512359817, 'min_child_weight': 8}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:31:24,130] Trial 40 finished with value: 0.8066465256797583 and parameters: {'n_estimators': 91, 'learning_rate': 0.3081182911423987, 'max_depth': 17, 'subsample': 0.6349151755670257, 'min_child_weight': 6}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:31:25,816] Trial 41 finished with value: 0.8328298086606244 and parameters: {'n_estimators': 395, 'learning_rate': 0.033485193248316926, 'max_depth': 4, 'subsample': 0.7514337219235793, 'min_child_weight': 8}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:31:26,448] Trial 42 finished with value: 0.8210808996307486 and parameters: {'n_estimators': 164, 'learning_rate': 0.03672104827315497, 'max_depth': 3, 'subsample': 0.796652382837729, 'min_child_weight': 8}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:31:27,958] Trial 43 finished with value: 0.8116817724068479 and parameters: {'n_estimators': 280, 'learning_rate': 0.41304355360616396, 'max_depth': 5, 'subsample': 0.9924957515165733, 'min_child_weight': 7}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:31:32,265] Trial 44 finished with value: 0.8230949983215844 and parameters: {'n_estimators': 591, 'learning_rate': 0.06081897665966621, 'max_depth': 7, 'subsample': 0.733715060969751, 'min_child_weight': 8}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:31:34,554] Trial 45 finished with value: 0.829137294394092 and parameters: {'n_estimators': 550, 'learning_rate': 0.03132827727910132, 'max_depth': 4, 'subsample': 0.7353232265596132, 'min_child_weight': 6}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:31:37,880] Trial 46 finished with value: 0.8224236320913058 and parameters: {'n_estimators': 524, 'learning_rate': 0.06405719226167148, 'max_depth': 6, 'subsample': 0.6649652819992641, 'min_child_weight': 8}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:31:38,593] Trial 47 finished with value: 0.8190668009399127 and parameters: {'n_estimators': 36, 'learning_rate': 0.014254700893140158, 'max_depth': 8, 'subsample': 0.5308798759780625, 'min_child_weight': 7}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:31:41,801] Trial 48 finished with value: 0.8311513930849278 and parameters: {'n_estimators': 182, 'learning_rate': 0.038402806688786637, 'max_depth': 9, 'subsample': 0.7915644858394815, 'min_child_weight': 3}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:31:44,995] Trial 49 finished with value: 0.8116817724068479 and parameters: {'n_estimators': 463, 'learning_rate': 0.12408737884283565, 'max_depth': 6, 'subsample': 0.501034335068395, 'min_child_weight': 4}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:31:48,598] Trial 50 finished with value: 0.8029540114132259 and parameters: {'n_estimators': 710, 'learning_rate': 0.49295593897073614, 'max_depth': 7, 'subsample': 0.8498441788511275, 'min_child_weight': 7}. Best is trial 10 with value: 0.8331654917757637.
# [I 2025-03-03 12:31:51,776] Trial 51 finished with value: 0.8375293722725747 and parameters: {'n_estimators': 183, 'learning_rate': 0.044896604448038155, 'max_depth': 9, 'subsample': 0.7749763059791426, 'min_child_weight': 3}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:31:54,065] Trial 52 finished with value: 0.8284659281638134 and parameters: {'n_estimators': 111, 'learning_rate': 0.03178782850388833, 'max_depth': 11, 'subsample': 0.7585684196465212, 'min_child_weight': 6}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:31:59,910] Trial 53 finished with value: 0.8314870762000671 and parameters: {'n_estimators': 310, 'learning_rate': 0.09094320994018802, 'max_depth': 12, 'subsample': 0.8108405101988608, 'min_child_weight': 2}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:32:05,806] Trial 54 finished with value: 0.8254447801275596 and parameters: {'n_estimators': 300, 'learning_rate': 0.09409922466059381, 'max_depth': 12, 'subsample': 0.8215645849678552, 'min_child_weight': 2}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:32:13,201] Trial 55 finished with value: 0.8277945619335347 and parameters: {'n_estimators': 393, 'learning_rate': 0.06865264649216432, 'max_depth': 9, 'subsample': 0.8619995493212245, 'min_child_weight': 1}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:32:20,045] Trial 56 finished with value: 0.8220879489761665 and parameters: {'n_estimators': 157, 'learning_rate': 0.011391704762536179, 'max_depth': 13, 'subsample': 0.7973357408618994, 'min_child_weight': 2}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:32:26,528] Trial 57 finished with value: 0.8177240684793555 and parameters: {'n_estimators': 818, 'learning_rate': 0.1638419254822712, 'max_depth': 15, 'subsample': 0.7783314310595707, 'min_child_weight': 3}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:32:37,254] Trial 58 finished with value: 0.8274588788183954 and parameters: {'n_estimators': 997, 'learning_rate': 0.05367574730106543, 'max_depth': 8, 'subsample': 0.7236225308880135, 'min_child_weight': 1}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:32:41,237] Trial 59 finished with value: 0.8220879489761665 and parameters: {'n_estimators': 357, 'learning_rate': 0.24820271859477588, 'max_depth': 12, 'subsample': 0.815004021003835, 'min_child_weight': 2}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:32:47,865] Trial 60 finished with value: 0.818395434709634 and parameters: {'n_estimators': 909, 'learning_rate': 0.10921106894383256, 'max_depth': 7, 'subsample': 0.7673114564083742, 'min_child_weight': 3}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:32:48,970] Trial 61 finished with value: 0.8355152735817388 and parameters: {'n_estimators': 207, 'learning_rate': 0.03250978486528015, 'max_depth': 5, 'subsample': 0.5937204448492037, 'min_child_weight': 8}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:32:49,857] Trial 62 finished with value: 0.8288016112789527 and parameters: {'n_estimators': 196, 'learning_rate': 0.026071374948980222, 'max_depth': 4, 'subsample': 0.5905094094547789, 'min_child_weight': 8}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:32:50,872] Trial 63 finished with value: 0.8288016112789527 and parameters: {'n_estimators': 315, 'learning_rate': 0.07417550288801716, 'max_depth': 3, 'subsample': 0.5493379655861179, 'min_child_weight': 9}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:32:51,597] Trial 64 finished with value: 0.8284659281638134 and parameters: {'n_estimators': 271, 'learning_rate': 0.0511509803216161, 'max_depth': 2, 'subsample': 0.745073055436456, 'min_child_weight': 8}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:32:59,542] Trial 65 finished with value: 0.8294729775092313 and parameters: {'n_estimators': 424, 'learning_rate': 0.024864305873634363, 'max_depth': 9, 'subsample': 0.9093841505750512, 'min_child_weight': 1}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:33:01,766] Trial 66 finished with value: 0.8267875125881168 and parameters: {'n_estimators': 217, 'learning_rate': 0.05303745915760968, 'max_depth': 10, 'subsample': 0.8421709211671863, 'min_child_weight': 10}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:33:04,510] Trial 67 finished with value: 0.8301443437395098 and parameters: {'n_estimators': 140, 'learning_rate': 0.0808264494036574, 'max_depth': 11, 'subsample': 0.5658629098373337, 'min_child_weight': 2}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:33:05,223] Trial 68 finished with value: 0.815038603558241 and parameters: {'n_estimators': 78, 'learning_rate': 0.016607501103012758, 'max_depth': 6, 'subsample': 0.6787369101358682, 'min_child_weight': 9}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:33:08,324] Trial 69 finished with value: 0.8220879489761665 and parameters: {'n_estimators': 672, 'learning_rate': 0.0973528385003048, 'max_depth': 5, 'subsample': 0.863453249878878, 'min_child_weight': 8}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:33:11,303] Trial 70 finished with value: 0.8200738502853306 and parameters: {'n_estimators': 298, 'learning_rate': 0.04858673613814653, 'max_depth': 8, 'subsample': 0.5152461320234173, 'min_child_weight': 5}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:33:12,647] Trial 71 finished with value: 0.8351795904665995 and parameters: {'n_estimators': 235, 'learning_rate': 0.029614264890535008, 'max_depth': 5, 'subsample': 0.6074725982045299, 'min_child_weight': 7}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:33:14,635] Trial 72 finished with value: 0.8328298086606244 and parameters: {'n_estimators': 493, 'learning_rate': 0.026320300220046333, 'max_depth': 4, 'subsample': 0.6490774550654881, 'min_child_weight': 7}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:33:17,144] Trial 73 finished with value: 0.8301443437395098 and parameters: {'n_estimators': 629, 'learning_rate': 0.02728178338262763, 'max_depth': 4, 'subsample': 0.6242907625278143, 'min_child_weight': 7}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:33:18,362] Trial 74 finished with value: 0.8301443437395098 and parameters: {'n_estimators': 474, 'learning_rate': 0.04400864410678654, 'max_depth': 2, 'subsample': 0.6467925316842361, 'min_child_weight': 6}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:33:21,424] Trial 75 finished with value: 0.8351795904665995 and parameters: {'n_estimators': 567, 'learning_rate': 0.010317043607314336, 'max_depth': 5, 'subsample': 0.5980435958388174, 'min_child_weight': 7}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:33:24,448] Trial 76 finished with value: 0.8351795904665995 and parameters: {'n_estimators': 595, 'learning_rate': 0.011595906176736557, 'max_depth': 5, 'subsample': 0.5966093485885033, 'min_child_weight': 8}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:33:27,479] Trial 77 finished with value: 0.8328298086606244 and parameters: {'n_estimators': 576, 'learning_rate': 0.010611141389850948, 'max_depth': 5, 'subsample': 0.6011506562185712, 'min_child_weight': 7}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:33:31,883] Trial 78 finished with value: 0.8157099697885196 and parameters: {'n_estimators': 735, 'learning_rate': 0.06658499560915807, 'max_depth': 6, 'subsample': 0.5838267946458264, 'min_child_weight': 6}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:33:36,559] Trial 79 finished with value: 0.8298086606243706 and parameters: {'n_estimators': 606, 'learning_rate': 0.0217146727673394, 'max_depth': 7, 'subsample': 0.5600071795735525, 'min_child_weight': 7}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:33:39,868] Trial 80 finished with value: 0.8200738502853306 and parameters: {'n_estimators': 535, 'learning_rate': 0.04238564764346253, 'max_depth': 6, 'subsample': 0.5386789586121744, 'min_child_weight': 8}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:33:42,872] Trial 81 finished with value: 0.8308157099697885 and parameters: {'n_estimators': 559, 'learning_rate': 0.010447907408276743, 'max_depth': 5, 'subsample': 0.59306860924097, 'min_child_weight': 8}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:33:44,921] Trial 82 finished with value: 0.8284659281638134 and parameters: {'n_estimators': 650, 'learning_rate': 0.03407408457492695, 'max_depth': 3, 'subsample': 0.6147349674689309, 'min_child_weight': 9}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:33:48,286] Trial 83 finished with value: 0.8180597515944948 and parameters: {'n_estimators': 683, 'learning_rate': 0.061739505451500455, 'max_depth': 5, 'subsample': 0.5766395302119338, 'min_child_weight': 8}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:33:50,120] Trial 84 finished with value: 0.8308157099697885 and parameters: {'n_estimators': 204, 'learning_rate': 0.028805272222932957, 'max_depth': 7, 'subsample': 0.6305686149652104, 'min_child_weight': 7}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:33:52,281] Trial 85 finished with value: 0.8039610607586438 and parameters: {'n_estimators': 434, 'learning_rate': 0.36710251815302, 'max_depth': 5, 'subsample': 0.6999845109601465, 'min_child_weight': 9}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:33:53,925] Trial 86 finished with value: 0.824773413897281 and parameters: {'n_estimators': 242, 'learning_rate': 0.04442043416446488, 'max_depth': 6, 'subsample': 0.6026625253035903, 'min_child_weight': 8}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:33:55,513] Trial 87 finished with value: 0.8274588788183954 and parameters: {'n_estimators': 499, 'learning_rate': 0.07459771384883969, 'max_depth': 3, 'subsample': 0.6149653796681327, 'min_child_weight': 7}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:33:58,083] Trial 88 finished with value: 0.8294729775092313 and parameters: {'n_estimators': 611, 'learning_rate': 0.022852699720348296, 'max_depth': 4, 'subsample': 0.5167467793465825, 'min_child_weight': 6}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:34:03,436] Trial 89 finished with value: 0.8190668009399127 and parameters: {'n_estimators': 573, 'learning_rate': 0.05740007367209354, 'max_depth': 8, 'subsample': 0.5441306272192992, 'min_child_weight': 8}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:34:04,734] Trial 90 finished with value: 0.8274588788183954 and parameters: {'n_estimators': 136, 'learning_rate': 0.03807245989615402, 'max_depth': 7, 'subsample': 0.663876253594355, 'min_child_weight': 7}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:34:06,954] Trial 91 finished with value: 0.8345082242363209 and parameters: {'n_estimators': 511, 'learning_rate': 0.023186066027714725, 'max_depth': 4, 'subsample': 0.5709423156973669, 'min_child_weight': 7}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:34:09,218] Trial 92 finished with value: 0.8321584424303458 and parameters: {'n_estimators': 526, 'learning_rate': 0.01637864751725439, 'max_depth': 4, 'subsample': 0.5712901409952618, 'min_child_weight': 7}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:34:09,484] Trial 93 finished with value: 0.7952332997650218 and parameters: {'n_estimators': 13, 'learning_rate': 0.03284338453523367, 'max_depth': 5, 'subsample': 0.5554951502313152, 'min_child_weight': 8}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:34:13,347] Trial 94 finished with value: 0.8324941255454851 and parameters: {'n_estimators': 491, 'learning_rate': 0.010848896036634605, 'max_depth': 6, 'subsample': 0.5827547183180394, 'min_child_weight': 6}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:34:16,202] Trial 95 finished with value: 0.8288016112789527 and parameters: {'n_estimators': 768, 'learning_rate': 0.05080347033051691, 'max_depth': 4, 'subsample': 0.5938578445714978, 'min_child_weight': 8}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:34:17,486] Trial 96 finished with value: 0.8304800268546492 and parameters: {'n_estimators': 386, 'learning_rate': 0.022265771373186333, 'max_depth': 3, 'subsample': 0.6395684465724449, 'min_child_weight': 7}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:34:20,808] Trial 97 finished with value: 0.8264518294729775 and parameters: {'n_estimators': 591, 'learning_rate': 0.039492604123834166, 'max_depth': 6, 'subsample': 0.6193845772690015, 'min_child_weight': 6}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:34:26,366] Trial 98 finished with value: 0.824773413897281 and parameters: {'n_estimators': 439, 'learning_rate': 0.06326343549794498, 'max_depth': 20, 'subsample': 0.561005121693038, 'min_child_weight': 5}. Best is trial 51 with value: 0.8375293722725747.
# [I 2025-03-03 12:34:29,616] Trial 99 finished with value: 0.8190668009399127 and parameters: {'n_estimators': 949, 'learning_rate': 0.08491627479628952, 'max_depth': 4, 'subsample': 0.7767992623201531, 'min_child_weight': 9}. Best is trial 51 with value: 0.8375293722725747.

# %%
model_xgb = XGBClassifier(**study.best_params)
model_xgb.fit(X_train, y_train_enc)
pred_xgb = model_xgb.predict(X_test)
precision_xgb = precision_score(y_test_enc, pred_xgb)
recall_xgb = recall_score(y_test_enc, pred_xgb)
f1_xgb= f1_score(y_test_enc, pred_xgb)
print('Precision:', precision_xgb)
print('Recall:', recall_xgb)
print('F1:', f1_xgb)
# Out:
# Precision: 0.8642066420664206
# Recall: 0.7960571040108769
# F1: 0.8287331917905166

# %%
from sklearn.ensemble import RandomForestClassifier
def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 10, 1000)
    max_depth = trial.suggest_int('max_depth', 2, 20)
    bootstrap = trial.suggest_categorical('bootstrap', [True, False])
    min_samples_split = trial.suggest_int('min_samples_split', 1, 10)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10)
    rfc = RandomForestClassifier(
        n_estimators = n_estimators,
        max_depth = max_depth,
        bootstrap = bootstrap,
        min_samples_split = min_samples_split,
        min_samples_leaf = min_samples_leaf
    )
    rfc.fit(X_train, y_train)
    pred_rfc = rfc.predict(X_test)
    accuracy = accuracy_score(y_test, pred_rfc)
    return accuracy
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2025-03-03 12:37:39,344] A new study created in memory with name: no-name-0a19b618-c557-4f49-9cc8-97f147af34cf
# [I 2025-03-03 12:38:01,934] Trial 0 finished with value: 0.8210808996307486 and parameters: {'n_estimators': 291, 'max_depth': 20, 'bootstrap': False, 'min_samples_split': 3, 'min_samples_leaf': 10}. Best is trial 0 with value: 0.8210808996307486.
# [I 2025-03-03 12:38:24,351] Trial 1 finished with value: 0.8157099697885196 and parameters: {'n_estimators': 387, 'max_depth': 10, 'bootstrap': False, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.8210808996307486.
# [I 2025-03-03 12:39:07,398] Trial 2 finished with value: 0.8180597515944948 and parameters: {'n_estimators': 825, 'max_depth': 16, 'bootstrap': True, 'min_samples_split': 3, 'min_samples_leaf': 5}. Best is trial 0 with value: 0.8210808996307486.
# [W 2025-03-03 12:39:07,400] Trial 3 failed with parameters: {'n_estimators': 85, 'max_depth': 12, 'bootstrap': True, 'min_samples_split': 1, 'min_samples_leaf': 1} because of the following error: InvalidParameterError("The 'min_samples_split' parameter of RandomForestClassifier must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.").
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Roaming\Python\Python313\site-packages\optuna\study\_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16232\1342665338.py", line 15, in objective
#     rfc.fit(X_train, y_train)
#     ~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\User\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\User\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of RandomForestClassifier must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.
# [W 2025-03-03 12:39:07,438] Trial 3 failed with value None.
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[10], line 20
#      18     return accuracy
#      19 study = optuna.create_study(direction='maximize')
# ---> 20 study.optimize(objective, n_trials=100)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\optuna\study\study.py:475, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     373 def optimize(
#     374     self,
#     375     func: ObjectiveFuncType,
#    (...)
#     382     show_progress_bar: bool = False,
#     383 ) -> None:
#     384     """Optimize an objective function.
#     385
#     386     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     473             If nested invocation of this method occurs.
#     474     """
# --> 475     _optimize(
#     476         study=self,
#     477         func=func,
#     478         n_trials=n_trials,
#     479         timeout=timeout,
#     480         n_jobs=n_jobs,
#     481         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     482         callbacks=callbacks,
#     483         gc_after_trial=gc_after_trial,
#     484         show_progress_bar=show_progress_bar,
#     485     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\optuna\study\_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\optuna\study\_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\optuna\study\_optimize.py:248, in _run_trial(study, func, catch)
#     241         assert False, "Should not reach."
#     243 if (
#     244     frozen_trial.state == TrialState.FAIL
#     245     and func_err is not None
#     246     and not isinstance(func_err, catch)
#     247 ):
# --> 248     raise func_err
#     249 return frozen_trial
#
# File ~\AppData\Roaming\Python\Python313\site-packages\optuna\study\_optimize.py:197, in _run_trial(study, func, catch)
#     195 with get_heartbeat_thread(trial._trial_id, study._storage):
#     196     try:
# --> 197         value_or_values = func(trial)
#     198     except exceptions.TrialPruned as e:
#     199         # TODO(mamu): Handle multi-objective cases.
#     200         state = TrialState.PRUNED
#
# Cell In[10], line 15, in objective(trial)
#       7 min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10)
#       8 rfc = RandomForestClassifier(
#       9     n_estimators = n_estimators,
#      10     max_depth = max_depth,
#    (...)
#      13     min_samples_leaf = min_samples_leaf
#      14 )
# ---> 15 rfc.fit(X_train, y_train)
#      16 pred_rfc = rfc.predict(X_test)
#      17 accuracy = accuracy_score(y_test, pred_rfc)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1382, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1377 partial_fit_and_fitted = (
#    1378     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1379 )
#    1381 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
#    1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:436, in BaseEstimator._validate_params(self)
#     428 def _validate_params(self):
#     429     """Validate types and values of constructor parameters
#     430
#     431     The expected type and values must be defined in the `_parameter_constraints`
#    (...)
#     434     accepted constraints.
#     435     """
# --> 436     validate_parameter_constraints(
#     437         self._parameter_constraints,
#     438         self.get_params(deep=False),
#     439         caller_name=self.__class__.__name__,
#     440     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\_param_validation.py:98, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      92 else:
#      93     constraints_str = (
#      94         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      95         f" {constraints[-1]}"
#      96     )
# ---> 98 raise InvalidParameterError(
#      99     f"The {param_name!r} parameter of {caller_name} must be"
#     100     f" {constraints_str}. Got {param_val!r} instead."
#     101 )
#
# InvalidParameterError: The 'min_samples_split' parameter of RandomForestClassifier must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.

# %%
rfc = RandomForestClassifier(**study.best_params)
rfc.fit(X_train, y_train)
pred_rfc = rfc.predict(X_test)
precision_rfc = precision_score(y_test, pred_rfc, pos_label='NORM')
recall_rfc = recall_score(y_test, pred_rfc, pos_label='NORM')
f1_rfc = f1_score(y_test, pred_rfc, pos_label='NORM')

# %%
print('Precision:', precision_rfc)
print('Recall:', recall_rfc)
print('F1:', f1_rfc)
# Out:
# Precision: 0.8017348203221809
# Recall: 0.8580901856763926
# F1: 0.8289557975656631
